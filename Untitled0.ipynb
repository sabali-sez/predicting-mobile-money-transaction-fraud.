# %% [markdown]
# <a href="https://colab.research.google.com/github/sabali-sez/predicting-mobile-money-transaction-fraud./blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from sklearn import preprocessing
from sklearn import utils

from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

from sklearn.preprocessing import PolynomialFeatures

data = pd.read_csv("/content/ResearchDataSet.csv")

data.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
data=data.drop(["nameOrig","nameDest","step","isFlaggedFraud" ,"type"],axis=1)

# %%
data.head()
# Out:
#      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  newbalanceDest  \
# 0   9839.64       170136.0       160296.36             0.0             0.0
# 1   1864.28        21249.0        19384.72             0.0             0.0
# 2    181.00          181.0            0.00             0.0             0.0
# 3    181.00          181.0            0.00         21182.0             0.0
# 4  11668.14        41554.0        29885.86             0.0             0.0
#
#    isFraud
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0

# %%
data = data.replace([np.inf, -np.inf], np.nan).fillna(1)

# %%
X = data.iloc[:,0:-1].values
y = data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2)

# %%
print(Xtrain.shape)
print(Xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (838860, 5)
# (209715, 5)
# (838860,)
# (209715,)

# %%
min_max_scaler=MinMaxScaler()
Xtrain=min_max_scaler.fit_transform(Xtrain)
Xtest=min_max_scaler.fit_transform(Xtest)

# %% [markdown]
# Random forest classfier

# %%
rf=RandomForestClassifier(max_features=0.2)
rf.fit(Xtrain,ytrain)

y_pred =rf.predict(Xtest)
pred_prob = rf.predict_proba(Xtest)

# %% [markdown]
# checking for acuracy score

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cmx=confusion_matrix(ytest,y_pred)
print(cmx)
print(accuracy_score(ytest,y_pred))
# Out:
# [[209488      7]
#  [    94    126]]
# 0.9995183940109196

# %%
data["isFraud"].value_counts()
# Out:
# isFraud
# 0    1047433
# 1       1142
# Name: count, dtype: int64

# %%
#clf = LogisticRegression(random_state=0).fit(Xtrain,ytrain)
#clf.predict(Xtrain,ytrain)
classifier = LogisticRegression(random_state=4)
classifier.fit(Xtrain,ytrain)

y_pred =rf.predict(Xtest)
pred_prob = rf.predict_proba(Xtest)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cmx2=confusion_matrix(ytest,y_pred)
print(cmx2)
print(accuracy_score(ytest,y_pred))
# Out:
# [[209488      7]
#  [    94    126]]
# 0.9995183940109196

# %% [markdown]
# descision tree

# %%
dtc=DecisionTreeClassifier()
dtc.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
dtc.fit(Xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
y_pred =dtc.predict(Xtest)
pred_prob = dtc.predict_proba(Xtest)

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cmx3=confusion_matrix(ytest,y_pred)
print(cmx3)
print(accuracy_score(ytest,y_pred))
# Out:
# [[209437     58]
#  [    75    145]]
# 0.9993658059747753

# %% [markdown]
# CLASSIFICATION REPORT

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    209495
#            1       0.71      0.66      0.69       220
#
#     accuracy                           1.00    209715
#    macro avg       0.86      0.83      0.84    209715
# weighted avg       1.00      1.00      1.00    209715
